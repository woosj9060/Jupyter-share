# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

##########데이터 로드

df = pd.DataFrame([
        ['A01', 2, 1, 60, 139, 'country', 0, 3],
        ['A02', 3, 2, 80, 148, 'country', 0, 5],
        ['A03', 3, 4, 50, 149, 'country', 0, 7],
        ['A04', 5, 5, 40, 151, 'country', 0, 10],
        ['A05', 7, 5, 35, 154, 'city', 0, 12],
        ['A06', 2, 5, 45, 149, 'country', 0, 7],
        ['A07',8, 9, 40, 155, 'city', 1, 13],
        ['A08', 9, 10, 70, 155, 'city', 3, 13],
        ['A09', 6, 12, 55, 154, 'city', 0, 12],
        ['A10', 9, 2, 40, 156, 'city', 1, 13],
        ['A11', 6, 10, 60, 153, 'city', 0, 12],
        ['A12', 2, 4, 75, 151, 'country', 0, 6]
    ], columns=['ID', 'hour', 'attendance', 'weight', 'iq', 'region', 'library', 'score'])

##########데이터 분석

s = df['region'].value_counts()
plt.pie(x=s, labels=s.index, autopct='%.1f%%', shadow=True)
plt.show()

# %%
import matplotlib.pyplot as plt
#matplotlib 패키지 한글 폰트 설정 시작
plt.rc('font', family='Malgun Gothic') #윈도우, 구글 콜랩
#plt.rc('font', family='AppleGothic') #맥
#matplotlib 패키지 한글 폰트 설정 끝

import matplotlib as mpl

#파이 차트 옵션 시작
mpl.rcParams['font.size'] = 10 #라벨 폰트 사이즈 디폴트값
plt.pie([1,2,3,4], labels=['A', 'B', 'C', 'D'], autopct='%.1f%%', shadow=True, startangle=90, explode=[0, 0.1, 0, 0], colors=['red', 'green', 'blue', 'gray']) #explode 0.1 B 는 중앙에서 10% 만큼 나오게
#파이 차트 옵션 끝
plt.title('파이 차트')
plt.show()

# %%
import json
import mpld3
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic') #윈도우, 구글 콜랩
#plt.rc('font', family='AppleGothic') #맥
#matplotlib 패키지 한글 폰트 설정 끝

import matplotlib as mpl

#파이 차트 옵션 시작
mpl.rcParams['font.size'] = 10 #라벨 폰트 사이즈 디폴트값
plt.pie([1,2,3,4], labels=['A', 'B', 'C', 'D'], autopct='%.1f%%', shadow=True, startangle=90, explode=[0, 0.1, 0, 0], colors=['red', 'green', 'blue', 'gray']) #explode 0.1 B 는 중앙에서 10% 만큼 나오게
#파이 차트 옵션 끝
plt.title('파이 차트')
plt.show()

f = plt.figure()

print(mpld3.fig_to_html(f, figid='THIS_IS_FIGID'))
# Out:
# <style>
#
# </style>
#
# <div id="THIS_IS_FIGID"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("THIS_IS_FIGID", {"width": 432.0, "height": 288.0, "axes": [], "data": {}, "id": "el16802967786824992", "plugins": [{"type": "reset"}, {"type": "zoom", "button": true, "enabled": false}, {"type": "boxzoom", "button": true, "enabled": false}]});
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://d3js.org/d3.v5"}});
# ...

# %%
import json
import mpld3
import matplotlib.pyplot as plt

f = plt.figure()
plt.plot([1,2,3], [4,5,6])
plt.show()

print(mpld3.fig_to_html(f, figid='THIS_IS_FIGID'))
# Out:
# <style>
#
# </style>
#
# <div id="THIS_IS_FIGID"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
# ...

# %%
import json
import mpld3
import matplotlib.pyplot as plt

f = plt.figure()
plt.rc('font', family='Malgun Gothic') #윈도우, 구글 콜랩
#plt.rc('font', family='AppleGothic') #맥
#matplotlib 패키지 한글 폰트 설정 끝

import matplotlib as mpl

#파이 차트 옵션 시작
mpl.rcParams['font.size'] = 10 #라벨 폰트 사이즈 디폴트값
plt.pie([1,2,3,4], labels=['A', 'B', 'C', 'D'], autopct='%.1f%%', shadow=True, startangle=90, explode=[0, 0.1, 0, 0], colors=['red', 'green', 'blue', 'gray']) #explode 0.1 B 는 중앙에서 10% 만큼 나오게
#파이 차트 옵션 끝
plt.title('파이 차트')
plt.show()

print(mpld3.fig_to_html(f, figid='THIS_IS_FIGID'))
# Out:
# <style>
#
# </style>
#
# <div id="THIS_IS_FIGID"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
# ...

# %%
import json
import mpld3
import matplotlib.pyplot as plt

f = plt.figure()
plt.rc('font', family='Malgun Gothic') #윈도우, 구글 콜랩
#plt.rc('font', family='AppleGothic') #맥
#matplotlib 패키지 한글 폰트 설정 끝

import matplotlib as mpl

#파이 차트 옵션 시작
mpl.rcParams['font.size'] = 10 #라벨 폰트 사이즈 디폴트값
plt.pie([1,2,3,4], labels=['A', 'B', 'C', 'D'], autopct='%.1f%%', shadow=True, startangle=90,, colors=['red', 'green', 'blue', 'gray']) #explode 0.1 B 는 중앙에서 10% 만큼 나오게
#파이 차트 옵션 끝
plt.title('파이 차트')
plt.show()

print(mpld3.fig_to_html(f, figid='THIS_IS_FIGID'))
# Out:
#   File "<ipython-input-7-e6da9e7a9ed8>", line 14
#     plt.pie([1,2,3,4], labels=['A', 'B', 'C', 'D'], autopct='%.1f%%', shadow=True, startangle=90,, colors=['red', 'green', 'blue', 'gray']) #explode 0.1 B 는 중앙에서 10% 만큼 나오게
#                                                                                                  ^
# SyntaxError: invalid syntax

# %%
import json
import mpld3
import matplotlib.pyplot as plt

f = plt.figure()

import matplotlib as mpl

#파이 차트 옵션 시작
plt.pie([1,2,3,4], labels=['A', 'B', 'C', 'D'], colors=['red', 'green', 'blue', 'gray'])
#파이 차트 옵션 끝
plt.show()

print(mpld3.fig_to_html(f, figid='THIS_IS_FIGID'))
# Out:
# <style>
#
# </style>
#
# <div id="THIS_IS_FIGID"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
# ...

# %%
import json
import mpld3
import matplotlib.pyplot as plt

f = plt.figure()

import matplotlib as mpl

#파이 차트 옵션 시작
plt.pie([2,2,4,5], labels=['A', 'B', 'C', 'D'], colors=['red', 'green', 'blue', 'gray'])
#파이 차트 옵션 끝
plt.show()

print(mpld3.fig_to_html(f, figid='PIE2'))
# Out:
# <style>
#
# </style>
#
# <div id="PIE2"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
# ...
